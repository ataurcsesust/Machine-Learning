# %%
print("Machine Learing")
# Out:
# Machine Learing

# %%
print("Machine Learing"+"Project")
# Out:
# Machine LearingProject

# %%
print(5+28)
# Out:
# 33

# %% [markdown]
# Basic Data types:
# 1.   int
# 2.   float
# 3.   str

# %%
type(5)
# Out:
# int

# %%
type('ataur')
# Out:
# str

# %%
type(4.3)
# Out:
# float

# %% [markdown]
# Constants & Variables

# %%
name = "ataur rahman"
print(name)
# Out:
# ataur rahman

# %%
hero1 , hero2 , hero3 , num= "Iron Man" , "Captain America" , "Bat Man",6
print(hero1)
print(hero2)
print(hero3)
print(num)
# Out:
# Iron Man
# Captain America
# Bat Man
# 6

# %%
x = y = z = 23
print(x)
print(y)
print(z)
# Out:
# 23
# 23
# 23

# %%
number_1 = int(input("Enter the first number : "))
number_2 = int(input("Enter the second number : "))

sum = number_1 + number_2
print(sum)

# %% [markdown]
# changing the data type in python

# %%
num = 5
print(float(num))
